# %%
import pandas as pd
df = pd.read_csv("Automobile_data.csv")
df.head(10)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
# 5      5         audi        sedan        99.8   177.3         ohc
# 6      6         audi        wagon       105.8   192.7         ohc
# 7      9          bmw        sedan       101.2   176.8         ohc
# 8     10          bmw        sedan       101.2   176.8         ohc
# 9     11          bmw        sedan       101.2   176.8         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# ...

# %% [markdown]
# #Para imprimir los 10 primeros carros se debe poner .head y en paréntesis la cantidad de carros

# %%
import pandas as pd
df = pd.read_csv("Automobile_data.csv")
df.tail(5)
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %% [markdown]
# #Para imprimir los últimos carros de la lista se debe poner .tail y en paréntesis la cantidad de carros

# %%
df = pd.read_csv("Automobile_data.csv", na_values={
'price':["?","n.a"],
'stroke':["?","n.a"],
'horsepower':["?","n.a"],
'peak-rpm':["?","n.a"],
'average-mileage':["?","n.a"]})
print (df)

df.to_csv("Automobile_data.csv")
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  index      company   body-style  \
# 0            0             0               0      0  alfa-romero  convertible
# 1            1             1               1      1  alfa-romero  convertible
# 2            2             2               2      2  alfa-romero    hatchback
# 3            3             3               3      3         audi        sedan
# 4            4             4               4      4         audi        sedan
# ..         ...           ...             ...    ...          ...          ...
# 56          56            56              56     81   volkswagen        sedan
# 57          57            57              57     82   volkswagen        sedan
# 58          58            58              58     86   volkswagen        sedan
# 59          59            59              59     87        volvo        sedan
# 60          60            60              60     88        volvo        wagon
#
# ...

# %% [markdown]
# #Dandole ?,n.a o NaN se brorran los datos del automóvil.

# %%
import pandas as pd
df = pd.read_csv("Automobile_data.csv")
df = df [['company','price']][df.price==df['price'].max()]
df
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %% [markdown]
# #Utilizando el .price seguido de doble igual además de df['price'].max(), mostrará el vehículo más caro.

# %%
import pandas as pd
df = pd.read_csv("Automobile_data.csv")
car_Manufacturers = df.groupby('company')
toyotaDf = car_Manufacturers.get_group('toyota')
toyotaDf
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  index company  \
# 48          48            48              48                48     66  toyota
# 49          49            49              49                49     67  toyota
# 50          50            50              50                50     68  toyota
# 51          51            51              51                51     69  toyota
# 52          52            52              52                52     70  toyota
# 53          53            53              53                53     71  toyota
# 54          54            54              54                54     79  toyota
#
#    body-style  wheel-base  length engine-type num-of-cylinders  horsepower  \
# 48  hatchback        95.7   158.7         ohc             four          62
# 49  hatchback        95.7   158.7         ohc             four          62
# 50  hatchback        95.7   158.7         ohc             four          62
# ...

# %% [markdown]
# #Mostrará la lista de carros de una compañía al darle car_Manufacturers = df.groupby('company')
# "compañía"Df = car_Manufacturers.get_group('compañía')

# %%
import pandas as pd
df = pd.read_csv("Automobile_data.csv")
df['company'].value_counts()
# Out:
# toyota           7
# bmw              6
# nissan           5
# mazda            5
# mitsubishi       4
# audi             4
# mercedes-benz    4
# volkswagen       4
# chevrolet        3
# porsche          3
# alfa-romero      3
# jaguar           3
# isuzu            3
# honda            3
# volvo            2
# dodge            2
# Name: company, dtype: int64

# %% [markdown]
# #Al darle df['company'].value_counts() mostrará la lista de los vehículos que estan presente.

# %%
import pandas as pd
df = pd.read_csv("Automobile_data.csv")
car_Manufacturers = df.groupby('company')
priceDf = car_Manufacturers['company','price','horsepower'].max()
priceDf
# Out:
# <ipython-input-17-1fb644db0c0f>:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   priceDf = car_Manufacturers['company','price','horsepower'].max()
#                      company    price  horsepower
# company
# alfa-romero      alfa-romero  16500.0         154
# audi                    audi  18920.0         115
# bmw                      bmw  41315.0         182
# chevrolet          chevrolet   6575.0          70
# dodge                  dodge   6377.0          68
# honda                  honda  12945.0         101
# isuzu                  isuzu   6785.0          78
# jaguar                jaguar  36000.0         262
# mazda                  mazda  18344.0         101
# mercedes-benz  mercedes-benz  45400.0         184
# mitsubishi        mitsubishi   8189.0          88
# nissan                nissan  13499.0         152
# porsche              porsche  37028.0         288
# ...

# %% [markdown]
# #En esta ocación se hará el precio y el caballaje más alto pero de cada compañía para esto se utilizaría priceDf = car_Manufacturers['company','price,'horsepower'].max()
# priceDf

# %%
import pandas as pd
df = pd.read_csv("Automobile_data.csv")
car_Manufacturers = df.groupby('company')
mileageDf = car_Manufacturers['company','average-mileage'].mean()
mileageDf
# Out:
# <ipython-input-18-a46696853d86>:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   mileageDf = car_Manufacturers['company','average-mileage'].mean()
#                average-mileage
# company
# alfa-romero          20.333333
# audi                 20.000000
# bmw                  19.000000
# chevrolet            41.000000
# dodge                31.000000
# honda                26.333333
# isuzu                33.333333
# jaguar               14.333333
# mazda                28.000000
# mercedes-benz        18.000000
# mitsubishi           29.500000
# nissan               31.400000
# porsche              17.000000
# toyota               28.714286
# volkswagen           31.750000
# volvo                23.000000

# %% [markdown]
# #Es muy parecido al del precio, pero en esta ocación se cambia el priceDf por mileageDf y en el paréntesis por average-mileage

# %%
import pandas as pd
carsDf = pd.read_csv("Automobile_data.csv")
carsDf = carsDf.sort_values(by=['price', 'horsepower'], ascending=False)
carsDf.head(15)
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  index  \
# 35          35            35              35                35     47
# 11          11            11              11                11     14
# 34          34            34              34                34     46
# 46          46            46              46                46     62
# 12          12            12              12                12     15
# 26          26            26              26                26     35
# 25          25            25              25                25     34
# 45          45            45              45                45     61
# 24          24            24              24                24     33
# 10          10            10              10                10     13
# 33          33            33              33                33     45
# 32          32            32              32                32     44
# ...

# %% [markdown]
# #Con la función carsDf = carsDf.sort_values(by=['price', 'horsepower'], ascending=False)y escogiendo la cantidad y poniendo si los primeros o últimos de la fila, se ordena los precios de los carros de mayor a menor

# %%
import pandas as pd

GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
carsDf1 = pd.DataFrame.from_dict(GermanCars)

japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}
carsDf2 = pd.DataFrame.from_dict(japaneseCars)

carsDf = pd.concat([carsDf1, carsDf2], keys=["Germany", "Japan"])
carsDf
# Out:
#                Company   Price
# Germany 0         Ford   23845
#         1     Mercedes  171995
#         2          BMV  135925
#         3         Audi   71400
# Japan   0       Toyota   29995
#         1        Honda   23600
#         2       Nissan   61500
#         3  Mitsubishi    58900

# %% [markdown]
# #Primero se crea una variable con el dato a comparar y las marcas y luego se inserta a un codigo llamado carsDf1 = pd.DataFrame.from_dict(nombre de la variable) y lo mismo para la segunda variable, lo que  cambia en ella es carsDf1 que en vez de eso va carsDf2. Por último se llama un carsDf = pd.concat([carsDf1, carsDf2], keys=[]

# %%
import pandas as pd

Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi','jaguar','chevrolet'], 'Price': [23845, 17995, 135925 , 71400,36000,6575]}
carPriceDf = pd.DataFrame.from_dict(Car_Price)

car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi','jaguar','chevrolet'], 'horsepower': [141, 80, 182 , 160,262,70]}
carsHorsepowerDf = pd.DataFrame.from_dict(car_Horsepower)

carsDf = pd.merge(carPriceDf, carsHorsepowerDf, on="Company")
carsDf
# Out:
#      Company   Price  horsepower
# 0     Toyota   23845         141
# 1      Honda   17995          80
# 2        BMV  135925         182
# 3       Audi   71400         160
# 4     jaguar   36000         262
# 5  chevrolet    6575          70

# %% [markdown]
# #Se crea dos variables y se definen con las marca, una variable para cada dato a comparar y luego se introducen en carsDf = pd.merge(carPriceDf, carsHorsepowerDf, on="Company")
